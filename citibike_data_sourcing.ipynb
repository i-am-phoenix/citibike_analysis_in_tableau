# %%
import pandas as pd
from io import BytesIO
import os
import glob
from urllib.request import urlopen
from zipfile import ZipFile
from urllib.parse import urlparse

# %%
# New format data is available from 09-2015 to 07-2021
years = list(range(2019,2022))
years
# Out:
# [2019, 2020, 2021]

# %%
months = list(range(5,8))
months
# Out:
# [5, 6, 7]

# %%
months_str =  [str(month).zfill(2) for month in months]
months_str
# Out:
# ['05', '06', '07']

# %%
# Cycle through years and months lists and generate rangle of zipped csv file urls to read data from
# exclude entries prior to September 2015
for year in years:
    for month in months:
        month_str = str(month).zfill(2)
        if ((year == 2015) & (month < 9)) :
            print("--")
        else :
            url="https://s3.amazonaws.com/tripdata/JC-"+ str(year) + month_str + "-citibike-tripdata.csv.zip"
#             print(url)

# %%
# Use zipfile library to unzip the csv files
for year in years:
    for month in months:
        # create a string representation of the month count with leading zeroes
        month_str = str(month).zfill(2)
        
        # check for exeptions
        if ((year == 2015) & (month < 9)) :
            print("-- data before Sep-2015 is out of scope")
        elif ((year == 2021) & (month > 7)) :
            print("-- data after Jul-2021 is unavailable")
        elif ((year == 2017) & (month == 8)) :
            # compose a unique url string for Aug 2017, as file name was mislabeled to contain space 
            # instead of a dash character after the year-month combination
            url="https://s3.amazonaws.com/tripdata/JC-201708%20citibike-tripdata.csv.zip"
        else :
            # compose url string  
            url="https://s3.amazonaws.com/tripdata/JC-"+ str(year) + month_str + "-citibike-tripdata.csv.zip"
            
        try :
            # use urlopen to access each zipped file online
            with urlopen(url) as zipresp:

                # cycle through each zip file 
                with ZipFile(BytesIO(zipresp.read())) as zfile:
                    print("Parsing " + str(year) + "-" + month_str +":" + url)
                    # extract content of each zip file into data directory
                    zfile.extractall('./data/')
        except :
            print("unable to parse url for " + str(year) + "-" + month_str)
# Out:
# Parsing 2019-05:https://s3.amazonaws.com/tripdata/JC-201905-citibike-tripdata.csv.zip
# Parsing 2019-06:https://s3.amazonaws.com/tripdata/JC-201906-citibike-tripdata.csv.zip
# Parsing 2019-07:https://s3.amazonaws.com/tripdata/JC-201907-citibike-tripdata.csv.zip
# Parsing 2020-05:https://s3.amazonaws.com/tripdata/JC-202005-citibike-tripdata.csv.zip
# Parsing 2020-06:https://s3.amazonaws.com/tripdata/JC-202006-citibike-tripdata.csv.zip
# Parsing 2020-07:https://s3.amazonaws.com/tripdata/JC-202007-citibike-tripdata.csv.zip
# Parsing 2021-05:https://s3.amazonaws.com/tripdata/JC-202105-citibike-tripdata.csv.zip
# Parsing 2021-06:https://s3.amazonaws.com/tripdata/JC-202106-citibike-tripdata.csv.zip
# Parsing 2021-07:https://s3.amazonaws.com/tripdata/JC-202107-citibike-tripdata.csv.zip

# %%
# Now concatenate all the csv files that were extracted
# Go down one level into the 'data' folder
os.chdir("./data")

# %%
# Match the pattern ‘csv’ and save the list of file names in the all_filenames variable. 
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['JC-201905-citibike-tripdata.csv',
#  'JC-201906-citibike-tripdata.csv',
#  'JC-201907-citibike-tripdata.csv',
#  'JC-202005-citibike-tripdata.csv',
#  'JC-202006-citibike-tripdata.csv',
#  'JC-202007-citibike-tripdata.csv',
#  'JC-202105-citibike-tripdata.csv',
#  'JC-202106-citibike-tripdata.csv',
#  'JC-202107-citibike-tripdata.csv']

# %%
test1 = pd.read_csv("JC-201907-citibike-tripdata.csv")
test2 = pd.read_csv("JC-202107-citibike-tripdata.csv")

# %%
# Review data in the old format
for col in test1.columns:
    print(f'\"{col}\": ,')
# Out:
# "tripduration": ,
# "starttime": ,
# "stoptime": ,
# "start station id": ,
# "start station name": ,
# "start station latitude": ,
# "start station longitude": ,
# "end station id": ,
# "end station name": ,
# "end station latitude": ,
# "end station longitude": ,
# "bikeid": ,
# "usertype": ,
# "birth year": ,
# "gender": ,

# %%
# Review data in teh new format
for col in test2.columns:
    print(f'\"{col}\"')
# Out:
# "ride_id"
# "rideable_type"
# "started_at"
# "ended_at"
# "start_station_name"
# "start_station_id"
# "end_station_name"
# "end_station_id"
# "start_lat"
# "start_lng"
# "end_lat"
# "end_lng"
# "member_casual"

# %%
# Reconcile column naming by performing blanket rename operation.
# First create dictionary of old vs new column names
col_name_reconcile = {
#     "tripduration": ,
    "starttime": "started_at",
    "stoptime": "ended_at",
    "start station id": "start_station_id",
    "start station name": "start_station_name",
    "start station latitude": "start_lat",
    "start station longitude": "start_lng",
    "end station id": "end_station_id",
    "end station name": "end_station_name",
    "end station latitude": "end_lat",
    "end station longitude": "end_lng",
#     "bikeid": ,
    "member_casual": "usertype"
#     "birth year": ,
#     "gender": 
}

# %%
# test1.rename(columns=col_name_reconcile, inplace=True)
# test1

# %%
# Match the member_casual(old) with usertype(new) columns, including corresponding variable values
df2cat = []
for f in all_filenames:
    a = pd.read_csv(f);
    a.rename(columns=col_name_reconcile, inplace=True)
    if "member_casual" in a.columns:
        a.rename(columns={"member_casual":"usertype"}, inplace=True)
    a['usertype']=a['usertype'].replace({"member" : "Subscriber", "casual" : "Customer"})
    df2cat.append(a)
df2cat
# Out:
# [       tripduration                started_at                  ended_at  \
#  0               311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
#  1               538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
#  2               178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
#  3               317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
#  4               354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#  ...             ...                       ...                       ...
#  36130           792  2019-05-31 23:51:00.1170  2019-06-01 00:04:12.4530
#  36131           779  2019-05-31 23:51:22.7840  2019-06-01 00:04:22.3990
#  36132           347  2019-05-31 23:55:38.3850  2019-06-01 00:01:26.2030
#  36133           552  2019-05-31 23:56:11.9740  2019-06-01 00:05:24.8810
#  36134           520  2019-05-31 23:56:25.0240  2019-06-01 00:05:05.4860
#
#         start_station_id  start_station_name  start_lat  start_lng  \
#  3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
#  4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
#  ...                 ...           ...                  ...
#  45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
#  45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
#  45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
#  45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
#  45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                    ended_at             start_station_name start_station_id  \
#  0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
#  1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
#  2      2021-05-25 17:03:06  9 St HBLR - Jackson St & 8 St            HB305
#  3      2021-05-22 17:41:27  9 St HBLR - Jackson St & 8 St            HB305
#  4      2021-05-14 10:17:36                       Union St            JC051
#  ...                    ...                            ...              ...
#  45038  2021-05-31 12:52:29              Clinton St & 7 St            HB303
#  45039  2021-05-31 16:59:21              Clinton St & 7 St            HB303
#  45040  2021-05-17 23:13:37                    Astor Place            JC077
#  45041  2021-05-31 21:16:02              Clinton St & 7 St            HB303
#  45042  2021-05-23 14:30:59              Clinton St & 7 St            HB303
#
#                      end_station_name end_station_id  start_lat  start_lng  \
#  0      9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
#  1      9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
#  2      9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
#  3                    Grand St & 2 St          HB405  40.747907 -74.038411
#  4                         Newark Ave          JC032  40.718211 -74.083639
#  ...                              ...            ...        ...        ...
#  45038               7 St & Monroe St          HB304  40.745420 -74.033320
#  45039              Clinton St & 7 St          HB303  40.745420 -74.033320
#  45040                    Astor Place          JC077  40.719282 -74.071261
#  45041              Clinton St & 7 St          HB303  40.745420 -74.033320
#  45042              Clinton St & 7 St          HB303  40.745420 -74.033320
#
#           end_lat    end_lng    usertype
#  0      40.747907 -74.038412    Customer
#  1      40.747907 -74.038412  Subscriber
#  2      40.747907 -74.038412    Customer
#  3      40.739130 -74.036180    Customer
#  4      40.721525 -74.046305    Customer
#  ...          ...        ...         ...
#  45038  40.746413 -74.037977    Customer
#  45039  40.745420 -74.033320    Customer
#  45040  40.719282 -74.071262    Customer
#  45041  40.745420 -74.033320    Customer
#  45042  40.745420 -74.033320    Customer
#
#  [45043 rows x 13 columns],
#                  ride_id rideable_type           started_at  \
#  0      6457BC38526A4187   docked_bike  2021-06-21 10:19:04
#  1      508AC0C37B2BE1A8   docked_bike  2021-06-05 10:12:18
#  2      A1AD52779E13308C   docked_bike  2021-06-04 15:42:35
#  3      DA8AA7083ACCA940   docked_bike  2021-06-03 18:07:42
#  4      BF8DB08AEF78C8D1   docked_bike  2021-06-05 15:39:56
#  ...                 ...           ...                  ...
#  71423  8DA32148B9DC1B15  classic_bike  2021-06-23 18:27:20
#  82548  16DF52E670465D19  classic_bike  2021-07-05 16:28:48
#
#                    ended_at          start_station_name start_station_id  \
#  0      2021-07-31 14:47:00     Bergen Ave & Stegman St            JC108
#  1      2021-07-17 19:20:07     Bergen Ave & Stegman St            JC108
#  2      2021-07-08 20:43:06  Columbus Dr at Exchange Pl            JC106
#  3      2021-07-18 20:28:23  Columbus Dr at Exchange Pl            JC106
#  4      2021-07-08 18:24:48  Columbus Dr at Exchange Pl            JC106
#  ...                    ...                         ...              ...
#  82544  2021-07-23 16:41:42               Grove St PATH            JC005
#  82545  2021-07-22 18:33:52               Grove St PATH            JC005
#  82546  2021-07-23 23:20:25               Grove St PATH            JC005
#  82547  2021-07-28 23:20:23               Grove St PATH            JC005
#  82548  2021-07-05 16:36:10               Grove St PATH            JC005
#
#                                     end_station_name end_station_id  start_lat  \
#  0      South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.706575
#  1                             Baldwin at Montgomery          JC020  40.706575
#  2                                Liberty Light Rail          JC052  40.716870
#  3                                         Warren St          JC006  40.716870
#  4                                         Warren St          JC006  40.716870
#  ...                                             ...            ...        ...
#  82544                            Liberty Light Rail          JC052  40.719586
#  82545                            Liberty Light Rail          JC052  40.719586
#  82546                            Liberty Light Rail          JC052  40.719586
#  82547                            Liberty Light Rail          JC052  40.719586
#  82548                            Liberty Light Rail          JC052  40.719586
#
#         start_lng    end_lat    end_lng    usertype
#  0     -74.086701  40.736982 -74.027781  Subscriber
#  1     -74.086701  40.723659 -74.064194  Subscriber
#  2     -74.032810  40.711242 -74.055701  Subscriber
#  3     -74.032810  40.721124 -74.038051  Subscriber
#  4     -74.032810  40.721124 -74.038051  Subscriber
#  ...          ...        ...        ...         ...
#  82544 -74.043117  40.711242 -74.055701    Customer
#  82545 -74.043117  40.711242 -74.055701    Customer
#  82546 -74.043117  40.711242 -74.055701    Customer
#  82547 -74.043117  40.711242 -74.055701    Customer
#  82548 -74.043117  40.711242 -74.055701    Customer
#
#  [82549 rows x 13 columns]]

# %%
#combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])
combined_csv = pd.concat(df2cat)
combined_csv.usertype.unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
combined_csv[combined_csv['tripduration'].isna()]['ended_at'].sort_values()
# Out:
# 22964    2021-05-01 00:07:11
# 22077    2021-05-01 00:13:55
# 42571    2021-05-01 00:26:00
# 42765    2021-05-01 00:26:00
# 33536    2021-05-01 00:41:51
#                 ...
# 25123    2021-08-01 13:55:10
# 59766    2021-08-01 15:03:00
# 24538    2021-08-01 20:23:24
# 25246    2021-08-01 21:25:49
# 25279    2021-08-01 21:50:34
# Name: ended_at, Length: 199020, dtype: object

# %%
#export to csv
combined_csv.to_csv( "JC-citibike-tripdata_combined.csv", index=False, encoding='utf-8-sig')

# %%
print(combined_csv.shape)
# Out:
# (419009, 17)

# %%
trans_all.to_csv("nd_trans_stations.csv", index=False, encoding='utf-8')
